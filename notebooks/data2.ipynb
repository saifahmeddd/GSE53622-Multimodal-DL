# %%
import pandas as pd
import numpy as np

# %%
# read excel files 
clinical_data = pd.read_excel('/Users/saifahmed/development/ESCC/data/GSE53622_clinical_data_of_patients_independent_set.xlsx', index_col=0)
lncRNA_data = pd.read_excel('/Users/saifahmed/development/ESCC/data/GSE53622_lncRNA_relative_expression_value_independent_set.xlsx', index_col=0)

# %%
clinical_data.head()
# Out:
#                   Age     Sex Tobacco use Alcohol use Tumor location  \
# Patient ID
# ec302       66.460274  female          no          no         middle
# ec303       64.013699    male         yes         yes         middle
# ec305       50.912329    male         yes         yes         middle
# ec306       46.328767    male         yes         yes          lower
# ec308       54.479452    male         yes         yes         middle
#
#            Tumor grade T stage N stage TNM stage Arrhythmia Pneumonia  \
# Patient ID
# ec302       moderately      T3      N2       III         no        no
# ec303       moderately      T3      N0        II        yes        no
# ec305       moderately      T3      N0        II         no        no
# ec306       moderately      T3      N0        II        yes        no
# ec308       moderately      T3      N1       III        yes        no
#
#            Anastomotic leak Adjuvant therapy Death at FU  \
# Patient ID
# ...

# %%
lncRNA_data.head()
# Out:
#                      ec302    ec303    ec305    ec306    ec308    ec309  \
# ID
# ENST00000230113.3  0.95164 -0.43897  0.66432  0.39730  1.10374  0.12260
# ENST00000244820.2  3.66153  0.00000  3.69433  1.05375  0.00000 -0.22875
# ENST00000244906.6  0.39562 -0.27769  0.05076 -0.35950  0.12267 -0.81289
# ENST00000253470.4  0.72692  0.21743  0.29066  0.53577  0.44644  0.37408
# ENST00000258817.2  1.62555  0.26386 -0.83020 -0.12628  1.23647  1.98821
#
#                      ec311    ec312    ec315    ec316  ...    ec398    ec400  \
# ID                                                     ...
# ENST00000230113.3 -1.40019 -0.41930 -0.33318  0.04630  ...  0.43920 -0.29970
# ENST00000244820.2  0.00000  0.26928  0.00000  0.00000  ...  3.45400 -0.68127
# ENST00000244906.6 -0.22533 -0.05881 -0.45828 -0.91320  ...  0.23748  0.32698
# ENST00000253470.4  0.46402  0.56782  0.47892  0.45962  ... -0.03028  0.23748
# ENST00000258817.2  0.78603 -0.68808  0.99714  0.57320  ... -0.57038  0.49780
#
# ...

# %%
clinical_data.columns
# Out:
# Index(['Age', 'Sex', 'Tobacco use', 'Alcohol use', 'Tumor location',
#        'Tumor grade', 'T stage', 'N stage', 'TNM stage', 'Arrhythmia',
#        'Pneumonia', 'Anastomotic leak', 'Adjuvant therapy', 'Death at FU',
#        'Survival time(months)'],
#       dtype='object')

# %%
clinical_data.index
# Out:
# Index(['ec302', 'ec303', 'ec305', 'ec306', 'ec308', 'ec309', 'ec311', 'ec312',
#        'ec315', 'ec316', 'ec317', 'ec318', 'ec319', 'ec321', 'ec322', 'ec324',
#        'ec325', 'ec326', 'ec330', 'ec331', 'ec333', 'ec334', 'ec337', 'ec338',
#        'ec340', 'ec341', 'ec342', 'ec347', 'ec353', 'ec355', 'ec361', 'ec362',
#        'ec365', 'ec366', 'ec367', 'ec370', 'ec371', 'ec373', 'ec374', 'ec375',
#        'ec376', 'ec378', 'ec380', 'ec381', 'ec382', 'ec385', 'ec391', 'ec392',
#        'ec393', 'ec396', 'ec398', 'ec400', 'ec402', 'ec403', 'ec404', 'ec405',
#        'ec406', 'ec407', 'ec408', 'ec409'],
#       dtype='object', name='Patient ID')
